# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen

news_url = "https://news.google.com/topstories?hl=id&gl=ID&ceid=ID:id"
Client = urlopen(news_url)
xml_page = Client.read()
Client.close()

soup_page = soup(xml_page, "xml")
news = soup_page.find("item")

#for news in news_list:
print(news.title.text)
print(news.link.text)
print(news.pubDate.text)
# Out:
# Response HTTP Status Code:  200
# ...

# %%
from pygooglenews import GoogleNews
import json
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_15828/2906402273.py in <module>
# ----> 1 from pygooglenews import GoogleNews
#       2 import json
#       3 import time
#
# ModuleNotFoundError: No module named 'pygooglenews'

# %%
# asession = AsyncHTMLSession()
# url = 'https://news.google.com/topstories?hl=id&gl=ID&ceid=ID:id'
# r = await asession.get(url)
# r.html.render(sleep=1, scrolldown=2)
# articles = r.html.find('article')
# print(articles)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_15828/434406881.py in <module>
#       2 url = 'https://news.google.com/topstories?hl=id&gl=ID&ceid=ID:id'
#       3 r = await asession.get(url)
# ----> 4 r.html.render(sleep=1, scrolldown=2)
#       5 articles = r.html.find('article')
#       6 print(articles)
#
# c:\Users\wis\miniconda3\envs\condawind\lib\site-packages\requests_html.py in render(self, retries, script, wait, scrolldown, sleep, reload, timeout, keep_page)
#     596                 try:
#     597
# --> 598                     content, result, page = self.session.loop.run_until_complete(self._async_render(url=self.url, script=script, sleep=sleep, wait=wait, content=self.html, reload=reload, scrolldown=scrolldown, timeout=timeout, keep_page=keep_page))
#     599                 except TypeError:
# ...

# %%
souppage = soup(xmlpage, 'xml')
newslist = souppage.findAll('item')
newslist
# Out:
# []
